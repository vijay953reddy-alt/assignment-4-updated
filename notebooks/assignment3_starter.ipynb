# %% [markdown]
# # Assignment 3 Starter Notebook
# This notebook helps you inspect Bronze, Silver, and Gold data for Pack A.

# %%
from pathlib import Path
import pandas as pd
BASE_DIR = Path('..').resolve() if Path.cwd().name == 'notebooks' else Path('assignment3_solution').resolve()
BASE_DIR

# %%
btc = pd.read_csv(BASE_DIR / 'data' / 'silver' / 'btc_daily_clean.csv')
btc.head()

# %%
fng = pd.read_csv(BASE_DIR / 'data' / 'silver' / 'fear_greed_clean.csv')
fng.head()

# %%
gold = pd.read_csv(BASE_DIR / 'data' / 'gold' / 'crypto_sentiment_daily.csv')
gold.head()

# %%
gold[['btc_daily_return']].describe()
